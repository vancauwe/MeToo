# %% [markdown]
# # Sentimental Analysis
#
# ## Importing and reading data
#
# **Dataset source** : https://data.world/rdeeds/350k-metoo-tweets
#
# **Content** : 350'000 tweets under the #MeToo hashtag dated between October 30th 2017 and February 8th 2018.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import csv
from collections import Counter
from collections import defaultdict

# %matplotlib inline

# %% [markdown]
# ### Load Data

# %%
data_folder = './data/'

# %%
twitter_data = pd.read_csv(data_folder+'metootweets.csv', error_bad_lines=False)
# Out:
# b'Skipping line 125: expected 14 fields, saw 15\nSkipping line 143: expected 14 fields, saw 15\nSkipping line 184: expected 14 fields, saw 15\nSkipping line 210: expected 14 fields, saw 15\nSkipping line 282: expected 14 fields, saw 15\nSkipping line 427: expected 14 fields, saw 15\nSkipping line 432: expected 14 fields, saw 17\nSkipping line 536: expected 14 fields, saw 17\nSkipping line 538: expected 14 fields, saw 15\nSkipping line 699: expected 14 fields, saw 15\nSkipping line 742: expected 14 fields, saw 16\nSkipping line 744: expected 14 fields, saw 17\nSkipping line 746: expected 14 fields, saw 17\nSkipping line 765: expected 14 fields, saw 15\nSkipping line 785: expected 14 fields, saw 15\nSkipping line 805: expected 14 fields, saw 15\nSkipping line 835: expected 14 fields, saw 15\nSkipping line 836: expected 14 fields, saw 15\nSkipping line 958: expected 14 fields, saw 15\nSkipping line 988: expected 14 fields, saw 15\nSkipping line 1058: expected 14 fields, saw 17\nSkipping line 1084: expected 14 fields, saw 15\nSkipping line 1109: expected 14 fields, saw 15\nSkipping line 1166: expected 14 fields, saw 15\nSkipping line 1219: expected 14 fields, saw 15\nSkipping line 1280: expected 14 fields, saw 16\nSkipping line 1287: expected 14 fields, saw 16\nSkipping line 1324: expected 14 fields, saw 15\nSkipping line 1333: expected 14 fields, saw 15\nSkipping line 1344: expected 14 fields, saw 15\nSkipping line 1460: expected 14 fields, saw 15\nSkipping line 1498: expected 14 fields, saw 16\nSkipping line 1544: expected 14 fields, saw 15\nSkipping line 1612: expected 14 fields, saw 15\nSkipping line 1622: expected 14 fields, saw 15\nSkipping line 1705: expected 14 fields, saw 15\nSkipping line 1742: expected 14 fields, saw 15\nSkipping line 1743: expected 14 fields, saw 17\nSkipping line 1753: expected 14 fields, saw 15\nSkipping line 1754: expected 14 fields, saw 17\nSkipping line 1770: expected 14 fields, saw 16\nSkipping line 1771: expected 14 fields, saw 15\nSkipping line 1787: expected 14 fields, saw 15\nSkipping line 1842: expected 14 fields, saw 15\nSkipping line 1959: expected 14 fields, saw 15\nSkipping line 2002: expected 14 fields, saw 15\nSkipping line 2031: expected 14 fields, saw 16\nSkipping line 2117: expected 14 fields, saw 15\nSkipping line 2151: expected 14 fields, saw 15\nSkipping line 2298: expected 14 fields, saw 15\nSkipping line 2372: expected 14 fields, saw 15\nSkipping line 2412: expected 14 fields, saw 15\nSkipping line 2501: expected 14 fields, saw 15\nSkipping line 2569: expected 14 fields, saw 16\nSkipping line 2
# 2  961730610824871936  Thu Feb 08 22:37:00 +0000 2018
# 3  961730619393810432  Thu Feb 08 22:37:02 +0000 2018
# 4  961730655506915328  Thu Feb 08 22:37:11 +0000 2018
#
#                                                 text      lastcontactdate  \
# 0  RT @IxAmandaDelgado: @Navegaciones @FelipeCald...  2015-01-01 00:00:00
# 1  RT @alexwitze: .@NSF will require institutions...  2015-01-01 00:00:00
# 2  Listening to the awesome feminist scholar Cynt...  2015-01-01 00:00:00
# 3  ??????????????????????????????????????????????...  2015-01-01 00:00:00
# 4  RT @AlbertoBernalLe: ?A ver, donde est?n todas...  2015-01-01 00:00:00
#
#       lasttimelinepull lasttimetweetsanalyzed numberoftweetsanalysed  \
# 0  2015-01-01 00:00:00    2015-01-01 00:00:00                      0
# 1  2015-01-01 00:00:00    2015-01-01 00:00:00                      0
# 2  2015-01-01 00:00:00    2015-01-01 00:00:00                      0
# 3  2015-01-01 00:00:00    2015-01-01 00:00:00                      0
# 4  2015-01-01 00:00:00    2015-01-01 00:00:00                      0
#
#   numberoftweetsabouthash actualtwitterdate
# 0                       0               NaN
# 1                       0               NaN
# 2                       0               NaN
# 3                       0               NaN
# 4                       0               NaN

# %% [markdown]
# ### Take only the tweets

# %%
tweets=twitter_data['text']
tweets_array=np.array(tweets)

# %% [markdown]
# ### Create the LIWC tool from the .txt file

# %%
def get_liwc_groups():
    """ 
    Parses LIWC file
    return:
    - {word with suffixed endings : [LIWC groups]}
    - {LIWC group : set([complete words])}
    - [liwc group names]
    """
    liwc = open('en_liwc.txt', 'r')
    star_words = defaultdict(list) # prefix : categories
    all_words = defaultdict(set) # category : words 
    liwc_names = [] 
    for line in liwc:
        l = line.split()
        g = l[0]
        liwc_names.append(g)
        words = l[1:]
        for w in words:
            w = w.lower()
            if w.endswith('*'):
                w = w[:-1]
                star_words[w].append(g)
            else:
                all_words[g].add(w) 
    liwc.close()
    return star_words, all_words, liwc_names

# %%
#liwc names is the ladders to qualify the text
star_words, all_words, liwc_names = get_liwc_groups()

# %% [markdown]
# We take a look at all the LIWC categories

# %%
liwc_names
# Out:
# ['Ppron:',
#  'Inhib:',
#  'Space:',
#  'Filler:',
#  'Ipron:',
#  'Time:',
#  'Percept:',
#  'Verbs:',
#  'Quant:',
#  'Discrep:',
#  'Relativ:',
#  'Affect:',
#  'You:',
#  'Cause:',
#  'Prep:',
#  'Relig:',
#  'Body:',
#  'Bio:',
#  'We:',
#  'Assent:',
#  'Incl:',
#  'Leisure:',
#  'AuxVb:',
#  'Hear:',
#  'They:',
#  'Posemo:',
#  'Article:',
#  'Excl:',
#  'Home:',
#  'Friends:',
#  'Present:',
#  'Numbers:',
#  'CogMech:',
#  'I:',
#  'Work:',
#  'Tentat:',
#  'Ingest:',
#  'Motion:',
#  'Anger:',
#  'Achiev:',
#  'Swear:',
#  'Death:',
#  'Social:',
#  'Nonflu:',
#  'Family:',
#  'Pronoun:',
#  'Funct:',
#  'Feel:',
#  'Certain:',
#  'Insight:',
#  'Humans:',
#  'Sad:',
#  'Past:',
#  'See:',
#  'Future:',
#  'Adverbs:',
#  'SheHe:',
#  'Money:',
#  'Negate:',
#  'Health:',
#  'Conj:',
#  'Anx:',
#  'Negemo:',
#  'Sexual:']

# %% [markdown]
# ### Apply the LIWC to our tweets

# %% [markdown]
# This function gets all LIWC categories for the given 'text' variable. The function will receive individually each tweet as 'text.'

# %%
def get_liwc_features(text):
    text = text.lower()
    text = re.sub("[^\w\d'\s]+", '', text)
    tok_counts = Counter(text.split())
    new_features = [0]*len(liwc_names)

    indices = {k: v for v, k in enumerate(liwc_names)}
    for g in all_words:
        new_features[indices[g]] += sum([c for x,c in tok_counts.items() if x in all_words[g]])
    for tok in tok_counts:
        for w in star_words:
            if tok.startswith(w): 
                groups = star_words[w]
                for g in groups:
                    new_features[indices[g]] += tok_counts[tok]
    return new_features

# %% [markdown]
# This function was designed to process all tweets by giving them individually to the get_liwc_features function. It creates a pandas DataFrame with the tweet itself and an array of the LIWC categories counted for that tweet.

# %%
def process_language_tweets(tweets):
    
    #create Dataframe to save all tweets and the identified features
    columns=['tweets','features']
    index=np.array(range(0,len(tweets)))
    features_per_tweet=pd.DataFrame(index=index,columns=columns)
    features_per_tweet['tweets']=tweets
    
    for i in range(len(tweets)):
        #reinitialize
        tweet_features=[]
        significant_features_id=[]
        
        #call LIWC on this tweet
        tweet_features_bool=np.array(get_liwc_features(str(tweets[i])))
        
        #from Boolean returned get IDs of significant features
        significant_features_id=np.where(tweet_features_bool==1);
        features_per_tweet['features'][i]=significant_features_id[0]
        
    return features_per_tweet

# %%
features_per_tweet=process_language_tweets(tweets_array)
features_per_tweet.head()
# Out:
#                                               tweets  \
# 0  RT @IxAmandaDelgado: @Navegaciones @FelipeCald...
# 1  RT @alexwitze: .@NSF will require institutions...
# 2  Listening to the awesome feminist scholar Cynt...
# 3  ??????????????????????????????????????????????...
# 4  RT @AlbertoBernalLe: ?A ver, donde est?n todas...
#
#                                            features
# 0                                   [0, 33, 45, 46]
# 1  [0, 1, 2, 9, 24, 26, 34, 37, 39, 49, 52, 54, 57]
# 2                      [10, 11, 19, 25, 34, 37, 55]
# 3                                                []
# 4                                              [58]

# %%
features_per_tweet.shape
# Out:
# (393207, 2)

# %%
twitter_data.shape
# Out:
# (393207, 14)

# %% [markdown]
# ### Saving the LIWC results per tweet

# %%
features_per_tweet.to_csv('features_per_tweet.csv')

# %% [markdown]
# ### Subsequent Analysis
#
# The next steps using the sentimental analysis will be to -for example- look at:
#
# - the feeling of implication : using the recurrence of categories such as "We", "They", "I" etc
# - the sentimental perception: using the recurrence of categories such as "Negemo", "Posemo", "Anger" etc
# - the temporal dimension: using the recurrence of categories such as "Past", "Future" etc
#
# Note: See README for further information
